# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.4.0 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: torchvision>=0.5.0 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from -r requirements.txt (line 2)) (0.16.0)
# Collecting dominate>=2.4.0 (from -r requirements.txt (line 3))
#   Downloading dominate-2.8.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting visdom>=0.1.8.8 (from -r requirements.txt (line 4))
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.4 MB 495.5 kB/s eta 0:00:03
#      ----------- ---------------------------- 0.4/1.4 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 9.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wandb (from -r requirements.txt (line 5))
#   Downloading wandb-0.15.12-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: filelock in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: sympy in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.1.2)
# Collecting fsspec (from torch>=1.4.0->-r requirements.txt (line 1))
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: requests in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (10.0.1)
# Collecting scipy (from visdom>=0.1.8.8->-r requirements.txt (line 4))
#   Downloading scipy-1.11.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (6.3.3)
# Requirement already satisfied: six in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.16.0)
# Collecting jsonpatch (from visdom>=0.1.8.8->-r requirements.txt (line 4))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (0.58.0)
# Collecting Click!=8.0.0,>=7.1 (from wandb->-r requirements.txt (line 5))
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->-r requirements.txt (line 5))
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from wandb->-r requirements.txt (line 5)) (5.9.0)
# Collecting sentry-sdk>=1.0.0 (from wandb->-r requirements.txt (line 5))
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb->-r requirements.txt (line 5))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from wandb->-r requirements.txt (line 5)) (6.0.1)
# Collecting pathtools (from wandb->-r requirements.txt (line 5))
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting setproctitle (from wandb->-r requirements.txt (line 5))
#   Downloading setproctitle-1.3.3-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from wandb->-r requirements.txt (line 5)) (68.0.0)
# Collecting appdirs>=1.4.3 (from wandb->-r requirements.txt (line 5))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb->-r requirements.txt (line 5))
#   Downloading protobuf-4.25.0-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: colorama in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from Click!=8.0.0,>=7.1->wandb->-r requirements.txt (line 5)) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from requests->torchvision>=0.5.0->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from jinja2->torch>=1.4.0->-r requirements.txt (line 1)) (2.1.1)
# Collecting jsonpointer>=1.9 (from jsonpatch->visdom>=0.1.8.8->-r requirements.txt (line 4))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\polcg\anaconda3\envs\tfg\lib\site-packages (from sympy->torch>=1.4.0->-r requirements.txt (line 1)) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading dominate-2.8.0-py2.py3-none-any.whl (29 kB)
# Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.1 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 26.5 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB ? eta 0:00:00
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.6 kB ? eta -:--:--
#    --------------------------------------- 190.6/190.6 kB 11.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.0-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.2 kB ? eta -:--:--
#    --------------------------------------- 413.2/413.2 kB 25.2 MB/s eta 0:00:00
# Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#    ---------------------------------------- 0.0/243.9 kB ? eta -:--:--
#    ---------------------------------------- 243.9/243.9 kB ? eta 0:00:00
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    --------------------------------------- 166.4/166.4 kB 10.4 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading scipy-1.11.3-cp310-cp310-win_amd64.whl (44.1 MB)
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    - -------------------------------------- 1.2/44.1 MB 38.6 MB/s eta 0:00:02
#    -- ------------------------------------- 2.2/44.1 MB 23.6 MB/s eta 0:00:02
#    --- ------------------------------------ 3.7/44.1 MB 26.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.0/44.1 MB 26.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.1/44.1 MB 26.1 MB/s eta 0:00:02
#    ------ --------------------------------- 7.6/44.1 MB 27.1 MB/s eta 0:00:02
#    -------- ------------------------------- 8.9/44.1 MB 27.2 MB/s eta 0:00:02
#    -------- ------------------------------- 9.2/44.1 MB 25.4 MB/s eta 0:00:02
#    --------- ------------------------------ 10.3/44.1 MB 25.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.7/44.1 MB 25.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 12.8/44.1 MB 25.2 MB/s eta 0:00:02
#    ------------ --------------------------- 14.0/44.1 MB 25.2 MB/s eta 0:00:02
#    ------------ --------------------------- 14.3/44.1 MB 23.4 MB/s eta 0:00:02
#    -------------- ------------------------- 15.6/44.1 MB 22.6 MB/s eta 0:00:02
#    --------------- ------------------------ 16.8/44.1 MB 22.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 18.2/44.1 MB 23.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 19.2/44.1 MB 23.4 MB/s eta 0:00:02
#    ------------------ --------------------- 20.1/44.1 MB 23.4 MB/s eta 0:00:02
#    ------------------- -------------------- 21.2/44.1 MB 23.4 MB/s eta 0:00:01
#    -------------------- ------------------- 22.6/44.1 MB 23.4 MB/s eta 0:00:01
#    --------------------- ------------------ 24.0/44.1 MB 24.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.3/44.1 MB 26.2 MB/s eta 0:00:01
#    ------------------------ --------------- 26.8/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------- -------------- 27.9/44.1 MB 27.3 MB/s eta 0:00:01
#    -------------------------- ------------- 29.2/44.1 MB 27.3 MB/s eta 0:00:01
#    --------------------------- ------------ 30.6/44.1 MB 28.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 31.3/44.1 MB 29.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.2/44.1 MB 26.2 MB/s eta 0:00:01
#    ------------------------------ --------- 33.6/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------------ --------- 33.8/44.1 MB 24.2 MB/s eta 0:00:01
#    ------------------------------- -------- 34.9/44.1 MB 23.4 MB/s eta 0:00:01
#    -------------------------------- ------- 36.1/44.1 MB 24.2 MB/s eta 0:00:01
#    --------------------------------- ------ 36.9/44.1 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.1/44.1 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.5/44.1 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------ --- 39.8/44.1 MB 20.5 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/44.1 MB 20.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.3/44.1 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------  43.2/44.1 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  43.3/44.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 44.1/44.1 MB 15.2 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-win_amd64.whl (11 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: visdom, pathtools
#   Building wheel for visdom (setup.py): started
#   Building wheel for visdom (setup.py): finished with status 'done'
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408308 sha256=55f1a595284ca7a5a2082a2095082356a9f637928275c303e4a7e4d08f3a1086
#   Stored in directory: c:\users\polcg\appdata\local\pip\cache\wheels\42\29\49\5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8802 sha256=0c1c8e8a0fce2bbded951eac1b60d59fb36772d657dc6fe1793d657b6e64635c
#   Stored in directory: c:\users\polcg\appdata\local\pip\cache\wheels\e7\f3\22\152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built visdom pathtools
# Installing collected packages: pathtools, appdirs, smmap, setproctitle, sentry-sdk, scipy, protobuf, jsonpointer, fsspec, dominate, docker-pycreds, Click, jsonpatch, gitdb, visdom, GitPython, wandb
# Successfully installed Click-8.1.7 GitPython-3.1.40 appdirs-1.4.4 docker-pycreds-0.4.0 dominate-2.8.0 fsspec-2023.10.0 gitdb-4.0.11 jsonpatch-1.33 jsonpointer-2.4 pathtools-0.1.2 protobuf-4.25.0 scipy-1.11.3 sentry-sdk-1.34.0 setproctitle-1.3.3 smmap-5.0.1 visdom-0.2.4 wandb-0.15.12

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, summer2winter_yosemite, horse2zebra, monet2photo, cezanne2photo, ukiyoe2photo, vangogh2photo, maps, cityscapes, facades, iphone2dslr_flower, ae_photos]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh horse2zebra

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_cyclegan_model.sh horse2zebra

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan --display_id -1

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png')
plt.imshow(img)
